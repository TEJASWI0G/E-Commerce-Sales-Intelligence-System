# %% [markdown]
# # E-Commerce Sales Intelligence System
# ## 02 — Data Cleaning & Preparation

# %%
import pandas as pd
import numpy as np

archive = "archive/"

customers = pd.read_csv(archive + "olist_customers_dataset.csv")
geolocation = pd.read_csv(archive + "olist_geolocation_dataset.csv")
orders = pd.read_csv(archive + "olist_orders_dataset.csv")
order_items = pd.read_csv(archive + "olist_order_items_dataset.csv")
order_payments = pd.read_csv(archive + "olist_order_payments_dataset.csv")
order_reviews = pd.read_csv(archive + "olist_order_reviews_dataset.csv")
products = pd.read_csv(archive + "olist_products_dataset.csv")
sellers = pd.read_csv(archive + "olist_sellers_dataset.csv")
product_translation = pd.read_csv(archive + "product_category_name_translation.csv")

# %% [markdown]
# ### Orders table

# %%
orders.info()
orders.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# #### Convert date columns to datetime

# %%
date_cols = [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_delivered_carrier_date",
    "order_delivered_customer_date",
    "order_estimated_delivery_date"
]

for col in date_cols:
    orders[col] = pd.to_datetime(orders[col], errors='coerce')

# %% [markdown]
# #### Understand missing values meaning

# %% [markdown]
# #### Create a Delivery Status Flag

# %%
orders["delivered_flag"] = orders["order_delivered_customer_date"].notna().astype(int)

# %% [markdown]
# #### Filter to only “completed/delivered” orders for revenue analysis

# %%
delivered_orders = orders[orders["order_status"] == "delivered"].copy()

# %% [markdown]
# #### Handle cancellations

# %%
cancelled_orders = orders[orders["order_status"] == "canceled"]

# %% [markdown]
# #### Check delivery delays

# %%
orders["delivery_time_days"] = (
    orders["order_delivered_customer_date"] - orders["order_purchase_timestamp"]
).dt.days

# %% [markdown]
# #### Estimate delay vs estimated

# %%
orders["estimated_time_days"] = (
    orders["order_estimated_delivery_date"] - orders["order_purchase_timestamp"]
).dt.days

# %%
orders["delay_days"] = orders["delivery_time_days"] - orders["estimated_time_days"]

# %% [markdown]
# ### Order_items Table

# %%
order_items.info()
order_items.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %% [markdown]
# #### Convert shipping_limit_date to datetime

# %%
order_items["shipping_limit_date"] = pd.to_datetime(
    order_items["shipping_limit_date"], 
    errors='coerce'
)

# %% [markdown]
# #### Create Total Item Value (Price + Freight)

# %%
order_items["total_item_value"] = order_items["price"] + order_items["freight_value"]

# %% [markdown]
# #### Calculate revenue per order

# %%
order_revenue = (
    order_items.groupby("order_id")["total_item_value"]
    .sum()
    .reset_index()
    .rename(columns={"total_item_value": "order_revenue"})
)

# %% [markdown]
# ### Product Table

# %%
products.info()
products.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# #### Merge product category translation

# %%
products = products.merge(
    product_translation,
    on="product_category_name",
    how="left"
)
# Because category names are Portuguese, and BI dashboards need English.
# Run this once to avoid duplicacy of columns

# %% [markdown]
# #### Handle missing product_category_name

# %%
products.columns
# Out:
# Index(['product_id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'product_category_name_english'],
#       dtype='object')

# %%
products["product_category_name"].fillna("unknown_category", inplace=True)
products["product_category_name_english"].fillna("Unknown", inplace=True)

# %% [markdown]
# ### Start Building the MASTER DATASET

# %% [markdown]
# ### Merge orders + order items

# %%
order_items_merged = orders.merge(
    order_items,
    on="order_id",
    how="inner"
)
order_items_merged.head()
# This gives you a row for every item purchased.
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date  delivered_flag  delivery_time_days  \
# 0                    2017-10-18               1                 8.0
# 1                    2018-08-13               1                13.0
# 2                    2018-09-04               1                 9.0
# 3                    2017-12-15               1                13.0
# 4                    2018-02-26               1                 2.0
#
#    estimated_time_days  delay_days  order_item_id  \
# 0                   15        -7.0              1
# 1                   19        -6.0              1
# 2                   26       -17.0              1
# 3                   26       -13.0              1
# 4                   12       -10.0              1
#
#                          product_id                         seller_id  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 1  595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 2  aa4383b373c6aca5d8797843e5594415  4869f7a5dfa277a7dca6462dcf3b52b2
# 3  d0b61bfb1de832b15ba9d266ca96e5b0  66922902710d126a0e7d26b0e3805106
# 4  65266b2da20d04dbe00c5c2d3bb7859e  2c9e548be18521d1c43cde1c582c6de8
#
#   shipping_limit_date   price  freight_value  total_item_value
# 0 2017-10-06 11:07:15   29.99           8.72             38.71
# 1 2018-07-30 03:24:27  118.70          22.76            141.46
# 2 2018-08-13 08:55:23  159.90          19.22            179.12
# 3 2017-11-23 19:45:59   45.00          27.20             72.20
# 4 2018-02-19 20:31:37   19.90           8.72             28.62

# %% [markdown]
# ### Then merge products

# %%
order_items_products = order_items_merged.merge(
    products,
    on="product_id",
    how="left"
)
order_items_products.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date  delivered_flag  delivery_time_days  ...  \
# 0                    2017-10-18               1                 8.0  ...
# 1                    2018-08-13               1                13.0  ...
# 2                    2018-09-04               1                 9.0  ...
# 3                    2017-12-15               1                13.0  ...
# 4                    2018-02-26               1                 2.0  ...
#
#    total_item_value  product_category_name  product_name_lenght  \
# 0             38.71  utilidades_domesticas                 40.0
# 1            141.46             perfumaria                 29.0
# 2            179.12             automotivo                 46.0
# 3             72.20               pet_shop                 59.0
# 4             28.62              papelaria                 38.0
#
#   product_description_lenght product_photos_qty product_weight_g  \
# 0                      268.0                4.0            500.0
# 1                      178.0                1.0            400.0
# 2                      232.0                1.0            420.0
# 3                      468.0                3.0            450.0
# 4                      316.0                4.0            250.0
#
#    product_length_cm  product_height_cm  product_width_cm  \
# 0               19.0                8.0              13.0
# 1               19.0               13.0              19.0
# 2               24.0               19.0              21.0
# 3               30.0               10.0              20.0
# 4               51.0               15.0              15.0
#
#   product_category_name_english
# 0                    housewares
# 1                     perfumery
# 2                          auto
# 3                      pet_shop
# 4                    stationery
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Then merge customers

# %%
full_data = order_items_products.merge(
    customers,
    on="customer_id",
    how="left"
)

# %% [markdown]
# ### Then merge sellers

# %%
full_data = full_data.merge(
    sellers,
    on="seller_id",
    how="left"
)

# %%
order_items_merged = orders.merge(order_items, on="order_id", how="inner")

# %% [markdown]
# ### Clean & Enhance the MASTER DATASET

# %% [markdown]
# #### Convert date columns to datetime

# %%
date_cols = [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_delivered_carrier_date",
    "order_delivered_customer_date",
    "order_estimated_delivery_date",
    "shipping_limit_date"
]

for col in date_cols:
    full_data[col] = pd.to_datetime(full_data[col], errors="coerce")

# %% [markdown]
# #### Create revenue & cost metrics

# %% [markdown]
# #### Actual revenue for each line item

# %%
full_data["item_revenue"] = full_data["price"]

# %% [markdown]
# #### Total cost of shipping paid by the customer

# %%
full_data["shipping_cost"] = full_data["freight_value"]

# %% [markdown]
# #### Delivery speed metrics

# %% [markdown]
# #### Number of days between purchase and customer delivery

# %%
full_data["delivery_days"] = (
    full_data["order_delivered_customer_date"] - full_data["order_purchase_timestamp"]
).dt.days

# %% [markdown]
# #### Number of days delayed (if delivered later than estimated)

# %%
full_data["delivery_delay"] = (
    full_data["order_delivered_customer_date"] - full_data["order_estimated_delivery_date"]
).dt.days

# %% [markdown]
# #### Filter to only delivered orders

# %%
full_data = full_data[full_data["order_status"] == "delivered"]

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110197 entries, 0 to 112649
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       110197 non-null  object
#  1   customer_id                    110197 non-null  object
#  2   order_status                   110197 non-null  object
#  3   order_purchase_timestamp       110197 non-null  datetime64[ns]
#  4   order_approved_at              110182 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   110195 non-null  datetime64[ns]
#  6   order_delivered_customer_date  110189 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  110197 non-null  datetime64[ns]
#  8   delivered_flag                 110197 non-null  int32
#  9   delivery_time_days             110189 non-null  float64
#  10  estimated_time_days            110197 non-null  int64
#  11  delay_days                     110189 non-null  float64
#  12  order_item_id                  110197 non-null  int64
#  13  product_id                     110197 non-null  object
#  14  seller_id                      110197 non-null  object
#  15  shipping_limit_date            110197 non-null  datetime64[ns]
#  16  price                          110197 non-null  float64
#  17  freight_value                  110197 non-null  float64
#  18  total_item_value               110197 non-null  float64
#  19  product_category_name          110197 non-null  object
#  20  product_name_lenght            108660 non-null  float64
#  21  product_description_lenght     108660 non-null  float64
#  22  product_photos_qty             108660 non-null  float64
#  23  product_weight_g               110179 non-null  float64
#  24  product_length_cm              110179 non-null  float64
#  25  product_height_cm              110179 non-null  float64
#  26  product_width_cm               110179 non-null  float64
#  27  product_category_name_english  110197 non-null  object
#  28  customer_unique_id             110197 non-null  object
#  29  customer_zip_code_prefix       110197 non-null  int64
#  30  customer_city                  110197 non-null  object
#  31  customer_state                 110197 non-null  object
#  32  seller_zip_code_prefix         110197 non-null  int64
#  33  seller_city                    110197 non-null  object
#  34  seller_state                   110197 non-null  object
#  35  item_revenue                   110197 non-null  float64
#  36  shipping_cost                  110197 non-null  float64
#  37  delivery_days                  110189 non-null  float64
#  38  delivery_delay                 110189 non-null  float64
# dtypes: datetime64[ns](6), float64(16), int32(1), int64(4), object(12)
# memory usage: 33.2+ MB

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# ### Basic KPIs

# %% [markdown]
# #### Total Revenue

# %%
total_revenue = full_data["item_revenue"].sum()
total_revenue
# Out:
# 13221498.110000001

# %% [markdown]
# #### Total Orders

# %%
total_orders = full_data["order_id"].nunique()
total_orders
# Out:
# 96478

# %% [markdown]
# #### Total Customers

# %%
total_customers = full_data["customer_unique_id"].nunique()
total_customers
# Out:
# 93358

# %% [markdown]
# #### Total Sellers

# %%
total_sellers = full_data["seller_id"].nunique()
total_sellers
# Out:
# 2970

# %% [markdown]
# ### Category-wise Revenue

# %%
category_revenue = (
    full_data.groupby("product_category_name_english")["item_revenue"]
    .sum()
    .sort_values(ascending=False)
)
category_revenue.head(10)
# Out:
# product_category_name_english
# health_beauty            1233131.72
# watches_gifts            1166176.98
# bed_bath_table           1023434.76
# sports_leisure            954852.55
# computers_accessories     888724.61
# furniture_decor           711927.69
# housewares                615628.69
# cool_stuff                610204.10
# auto                      578966.65
# toys                      471286.48
# Name: item_revenue, dtype: float64

# %% [markdown]
# ### Monthly Sales Trend

# %%
full_data["order_month"] = full_data["order_purchase_timestamp"].dt.to_period("M")

monthly_sales = (
    full_data.groupby("order_month")["item_revenue"]
    .sum()
    .reset_index()
)
monthly_sales.head()
# Out:
#   order_month  item_revenue
# 0     2016-09        134.97
# 1     2016-10      40325.11
# 2     2016-12         10.90
# 3     2017-01     111798.36
# 4     2017-02     234223.40

# %% [markdown]
# ### Delivery Performance

# %% [markdown]
# #### Average delivery days:

# %%
full_data["delivery_days"].mean()
# Out:
# 12.007341930682736

# %% [markdown]
# #### Average delay:

# %%
full_data["delivery_delay"].mean()
# Out:
# -12.02904101135322

# %% [markdown]
# 1. Monthly Revenue Analysis
# 2. Delivery Time Analysis
# 3. Customer Segmentation (RFM)
# 4. Cohort Retention Analysis
# 5. Payment Analytics
# 6. Product-Level Deep Dive
# 7. Seller Analysis
# 8. Geo Analysis
# 9. Review Score Analysis
# 10. Predictive Modeling

# %% [markdown]
# ## Exporting Dataset

# %%
# Check your variable name
# %whos
# Out:
# Variable               Type         Data/Info
# ---------------------------------------------
# archive                str          archive/
# cancelled_orders       DataFrame                             <...>n\n[625 rows x 9 columns]
# category_revenue       Series       product_category_name_eng<...>ength: 72, dtype: float64
# col                    str          shipping_limit_date
# customers              DataFrame                             <...>n[99441 rows x 5 columns]
# date_cols              list         n=6
# delivered_orders       DataFrame                             <...>n[96478 rows x 9 columns]
# full_data              DataFrame                             <...>110197 rows x 40 columns]
# geolocation            DataFrame             geolocation_zip_<...>1000163 rows x 5 columns]
# monthly_sales          DataFrame       order_month  item_reve<...>    2018-08     838576.64
# np                     module       <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# order_items            DataFrame                             <...>[112650 rows x 8 columns]
# order_items_merged     DataFrame                             <...>112650 rows x 19 columns]
# order_items_products   DataFrame                             <...>112650 rows x 28 columns]
# order_payments         DataFrame                             <...>[103886 rows x 5 columns]
# order_revenue          DataFrame                             <...>n[98666 rows x 2 columns]
# order_reviews          DataFrame                             <...>n[99224 rows x 7 columns]
# orders                 DataFrame                             <...>[99441 rows x 12 columns]
# pd                     module       <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# product_translation    DataFrame                product_categ<...>\n\n[71 rows x 2 columns]
# products               DataFrame                             <...>[32951 rows x 10 columns]
# sellers                DataFrame                             <...>\n[3095 rows x 4 columns]
# total_customers        int          93358
# total_orders           int          96478
# total_revenue          float64      13221498.110000001
# total_sellers          int          2970

# %%
full_data.to_csv("final_olist_dataset.csv", index=False)
